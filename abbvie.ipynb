# %%
#import libraries
import pandas as pd
import os

# %%
pwd
# Out:
# '/Users/marcosjohnsonnoya'

# %%
variable = pd.read_csv(r"/Users/marcosjohnsonnoya/Desktop/IBM.csv")
print(variable)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0     10/8/19  140.240005  140.470001  138.250000  138.380005  131.833969
# 1     10/9/19  139.770004  140.330002  138.789993  139.669998  133.062927
# 2    10/10/19  139.770004  141.779999  139.559998  141.130005  134.453857
# 3    10/11/19  142.770004  144.500000  142.610001  142.759995  136.006744
# 4    10/14/19  142.309998  142.429993  141.320007  142.039993  135.320816
# 5    10/15/19  142.539993  143.720001  141.809998  143.000000  136.235397
# 6    10/16/19  142.490005  142.949997  141.389999  142.110001  135.387497
# 7    10/17/19  135.000000  136.000000  132.910004  134.259995  127.908836
# 8    10/18/19  134.220001  134.490005  132.250000  134.089996  127.746880
# 9    10/21/19  132.610001  133.100006  130.899994  132.580002  126.308311
# 10   10/22/19  132.550003  134.050003  131.610001  133.960007  127.623032
# 11   10/23/19  133.520004  134.570007  132.699997  134.380005  128.023178
# ...
